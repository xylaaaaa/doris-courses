# %% [markdown]
# <div style="border-top:4px solid #0f766e;padding:32px 0 20px">
# <div style="color:#0f766e;font-size:13px;font-weight:700;letter-spacing:.8px">QUIZ METRIC-PROCESSING · DATA WAREHOUSING WITH APACHE DORIS</div>
# <div style="color:#17212b;font-size:30px;font-weight:750">Module 10: Metric processing and service delivery</div>
# <p style="color:#475569;font-size:15px;line-height:1.7">Five single-choice questions with immediate feedback. No database connection is required.</p>
# </div>
#
# [Course notes](course.md) · [Lab](lab10_metric_processing.ipynb)

# %% [markdown]
# ### Load the Quiz
#
# Run the next cell to load the quiz. After restarting the kernel, rerun from here.

# %%
from pathlib import Path
import sys

COURSE_ROOT = next(path for path in (Path.cwd(), *Path.cwd().parents) if (path / "dw_course").is_dir())
if str(COURSE_ROOT) not in sys.path:
    sys.path.insert(0, str(COURSE_ROOT))

from dw_course.quiz import CourseQuiz
from dw_course.runtime import COURSE_ROOT

quiz = CourseQuiz.from_yaml(COURSE_ROOT / "level2/module10-metric-processing/quiz10_metric_processing.yaml")

# %% [markdown]
# ## Start the Quiz
#
# Select and submit an answer, then read the explanation before moving to the next question.

# %%
quiz.show();
