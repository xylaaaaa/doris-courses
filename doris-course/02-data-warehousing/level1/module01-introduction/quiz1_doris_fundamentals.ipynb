# %% [markdown]
# <div style="max-width:100%;box-sizing:border-box;overflow:visible;border-top:4px solid #0f766e;padding:32px 0 20px;margin:0 0 24px">
#   <div style="display:block;color:#0f766e;font-size:13px;line-height:1.8;font-weight:700;letter-spacing:0.8px;text-transform:uppercase;margin:0 0 8px">QUIZ 1 · DATA WAREHOUSING WITH APACHE DORIS</div>
#   <div style="color:#17212b;font-size:30px;line-height:1.3;font-weight:750;margin:0 0 10px">Knowledge Quiz</div>
#   <p style="color:#475569;font-size:15px;line-height:1.7;max-width:900px;margin:0">Five single-choice questions with feedback after each question; no database connection required.</p>
#   <span style="display:inline-block;border:1px solid #99f6e4;border-radius:4px;background:#f0fdfa;color:#115e59;padding:6px 10px;margin-top:14px;font-size:12px">5 questions · Single choice · About 5 minutes</span>
# </div>
#
# [Course notes](course1_introduction_to_apache_doris.md) · [Lab](lab1_connect_and_query.ipynb)

# %% [markdown]
# ### Load the Quiz
#
# Run the next cell to load the quiz. After restarting the kernel, rerun from here.

# %%
from pathlib import Path
import sys

COURSE_ROOT = next(
    path for path in (Path.cwd(), *Path.cwd().parents)
    if (path / "dw_course").is_dir()
)
if str(COURSE_ROOT) not in sys.path:
    sys.path.insert(0, str(COURSE_ROOT))

from dw_course.quiz import CourseQuiz
from dw_course.runtime import COURSE_ROOT

quiz = CourseQuiz.from_yaml(COURSE_ROOT / "level1/module01-introduction/quiz1_doris_fundamentals.yaml")

# %% [markdown]
# ## Start the Quiz
#
# Select an answer and submit it, then read the explanation before moving to the next question.

# %%
quiz.show();
